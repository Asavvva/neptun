# %%
from netCDF4 import Dataset
import numpy as np

# %%
data = Dataset('/mnt/hippocamp/DATA/sattelite/SMOS/L2OS/MIR_OSUDP2_nc/2015/06/05/SM_REPR_MIR_OSUDP2_20150605T001719_20150605T011039_700_200_1.nc', 'r')
data.variables
# Out:
# {'Science_Flags_corr': <class 'netCDF4.Variable'>
#  uint32 Science_Flags_corr(n_grid_points)
#      _FillValue: 0
#      flag_masks: [     1      2      4      8     16     32     64    128    256    512
#     1024   2048   4096   8192  16384 -32768      0      0      0      0
#        0      0      0]
#      flag_values: [     1      2      4      8     16     32     64    128    256    512
#     1024   2048   4096   8192  16384 -32768      0      0      0      0
#        0      0      0]
#      flag_meanings: FG_SC_LAND_SEA_COAST1 FG_SC_LAND_SEA_COAST2 FG_SC_TEC_GRADIENT FG_SC_IN_CLIM_ICE FG_SC_ICE FG_SC_SUSPECT_ICE FG_SC_RAIN FG_SC_HIGH_WIND FG_SC_LOW_WIND FG_SC_HIGHT_SST FG_SC_LOW_SST FG_SC_HIGH_SSS FG_SC_LOW_SSS FG_SC_SEA_STATE_1 FG_SC_SEA_STATE_2 FG_SC_SEA_STATE_3 FG_SC_SEA_STATE_4 FG_SC_SEA_STATE_5 FG_SC_SEA_STATE_6 FG_SC_SST_FRONT FG_SC_SSS_FRONT FG_SC_ICE_ACARD FG_SC_ECMWF_LAND
#      _Unsigned: true
#  unlimited dimensions:
#  current shape = (98152,)
#  filling on,
# ...

# %%
lat = np.asarray(data['Latitude'])

# %%
lat
# Out:
# array([-80.148, -80.024, -80.063, ...,  78.138,  87.038,  75.083],
#       dtype=float32)
